# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense, Dropout, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import kneighbors_graph
from spektral.layers import GCNConv
import matplotlib.pyplot as plt

# ---------------------------
# Step 1: Data Collection & Preprocessing (GLORIA dataset example)
# ---------------------------

# Load GLORIA Dataset (replace with actual file paths)
meta_data_path = "GLORIA_meta_and_lab.csv"
rrs_data_path = "GLORIA_Rrs.csv"

# Load metadata and reflectance data
meta_data = pd.read_csv(meta_data_path)
rrs_data = pd.read_csv(rrs_data_path)

# Select relevant spectral bands (e.g., Rrs_443, Rrs_560, Rrs_665)
selected_bands = ['Rrs_443', 'Rrs_560', 'Rrs_665']
X_data = rrs_data[selected_bands].values

# Normalize the features to [0, 1]
scaler = MinMaxScaler()
X_norm = scaler.fit_transform(X_data)

# Extract chlorophyll-a values from metadata (assume the column name is 'Chla')
y_data = meta_data['Chla'].values  # Chlorophyll-a in µg/L

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_norm, y_data, test_size=0.2, random_state=42)

# Reshape X_train for the CNN branch: model expects (n_nodes, n_features, 1)
X_train_cnn = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_cnn = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# ---------------------------
# Step 2: Graph Construction
# ---------------------------
# Create an adjacency matrix using k-nearest neighbors (k=5)
A = kneighbors_graph(X_train, n_neighbors=5, mode='connectivity', include_self=True)
A = A.toarray().astype('float32')  # Adjacency matrix shape: (n_train, n_train)
A_tensor = tf.convert_to_tensor(A)  # Convert adjacency matrix to TensorFlow tensor

# ---------------------------
# Step 3: Build the Hybrid GNN-CNN Model
# ---------------------------

# Define two inputs: one for CNN branch and one for GNN branch
input_cnn = Input(shape=(X_train_cnn.shape[1], 1), name='cnn_input')  # CNN input: (features, 1)
input_gnn = Input(shape=(X_train.shape[1],), name='gnn_input')         # GNN input: (features)

# CNN Branch: Apply 1D convolution to extract local feature patterns from each node's feature vector.
cnn_branch = Conv1D(filters=16, kernel_size=2, activation='relu')(input_cnn)
cnn_branch = Flatten()(cnn_branch)

# GNN Branch: Use a Graph Convolutional Layer to capture spatial relationships across training samples.
gnn_branch = GCNConv(16, activation='relu')([input_gnn, A_tensor])
gnn_branch = Flatten()(gnn_branch)

# Merge the two branches
merged = Concatenate()([cnn_branch, gnn_branch])
dense1 = Dense(64, activation='relu')(merged)
drop1 = Dropout(0.3)(dense1)
output = Dense(1, name='prediction')(drop1)  # Regression output: predicting chlorophyll-a

# Define the model with two inputs
model = Model(inputs=[input_cnn, input_gnn], outputs=output)

# Compile the model with Adam optimizer and MSE loss function
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
model.summary()

# ---------------------------
# Step 4: Train the Model
# ---------------------------
history = model.fit([X_train_cnn, X_train], y_train,
                    epochs=50,
                    batch_size=16,
                    validation_split=0.2)

# ---------------------------
# Step 5: Model Evaluation and Visualization
# ---------------------------

loss, mae = model.evaluate([X_test_cnn, X_test], y_test)
print(f"\nTest Mean Absolute Error (MAE): {mae}")

# Plot training history: Loss and MAE over epochs
plt.figure(figsize=(12, 6))

# Plot Loss (MSE) over epochs
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend()
plt.title('Training vs Validation Loss')

# Plot MAE over epochs
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.title('Training vs Validation MAE')

plt.tight_layout()
plt.show()

# ---------------------------
# Step 6: Testing on New Data (Example)
# ---------------------------

new_sample_cnn = X_test_cnn[0].reshape(1, X_test_cnn.shape[1], 1)  # First test sample for CNN branch
new_sample_gnn = X_test[0].reshape(1, X_test.shape[1])             # First test sample for GNN branch

predicted_value = model.predict([new_sample_cnn, new_sample_gnn])
print(f"\nPredicted Chlorophyll-a for new sample: {predicted_value[0][0]:.3f} µg/L")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       9 from sklearn.model_selection import train_test_split
#      10 from sklearn.neighbors import kneighbors_graph
# ---> 11 from spektral.layers import GCNConv
#      12 import matplotlib.pyplot as plt
#      14 # ---------------------------
#      15 # Step 1: Data Collection & Preprocessing (GLORIA dataset example)
#      16 # ---------------------------
#      17
#      18 # Load GLORIA Dataset (replace with actual file paths)
#
# ModuleNotFoundError: No module named 'spektral'

# %%
pip install spektral
# Out:
# Collecting spektral
#   Downloading spektral-1.3.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: joblib in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from spektral) (1.4.2)
# Collecting lxml (from spektral)
#   Downloading lxml-5.3.1-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting networkx (from spektral)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from spektral) (2.0.2)
# Requirement already satisfied: pandas in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from spektral) (2.2.3)
# Requirement already satisfied: requests in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from spektral) (2.32.3)
# Requirement already satisfied: scikit-learn in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from spektral) (1.6.1)
# Requirement already satisfied: scipy in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from spektral) (1.15.1)
# Collecting tqdm (from spektral)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: tensorflow>=2.2.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from spektral) (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow>=2.2.0->spektral) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (3.4.0)
# Requirement already satisfied: packaging in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (5.29.3)
# Requirement already satisfied: setuptools in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (1.17.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (1.69.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from requests->spektral) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from requests->spektral) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from requests->spektral) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from requests->spektral) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from pandas->spektral) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from pandas->spektral) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from pandas->spektral) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->spektral) (3.5.0)
# Requirement already satisfied: colorama in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tqdm->spektral) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (0.45.1)
# Requirement already satisfied: rich in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (13.9.4)
# Requirement already satisfied: namex in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (0.0.8)
# Requirement already satisfied: optree in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (0.13.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\braedynm\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.2.0->spektral) (0.1.2)
# Downloading spektral-1.3.1-py3-none-any.whl (140 kB)
# Downloading lxml-5.3.1-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 22.8 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 31.8 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, networkx, lxml, spektral
# Successfully installed lxml-5.3.1 networkx-3.4.2 spektral-1.3.1 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
